# %% [markdown]
# Goal:
# Explore the Diabetes dataset, clean data, perform analysis, and visualize results using NumPy, Pandas, Matplotlib, and Seaborn.
# 1. Why This Project?
# - Learn data cleaning with Pandas.
#
# - Use NumPy for calculations (mean, median, etc.).
#
# - Visualize trends using Matplotlib and Seaborn.
#
# - Understand the relationship between  features

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 3 Load datset

# %%
df=pd.read_csv("diabetes.csv")
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 4 Exploring the data

# %%
print("Shape:", df.shape)
print(df.info())
print(df.isnull().sum())
print(df.describe())
# Out:
# Shape: (768, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# ...

# %% [markdown]
# Insights:
#
# 1.There are 768 records with multiple features (Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMIDiabetesPedigreeFunction,Age
# ).
#
# 2.No missing values found
#
# 3.Understanding these helps guide data cleaning.

# %% [markdown]
# 5 No data cleaning is needed as all values are present

# %% [markdown]
# 6 Analysis with Numpys and Pandas

# %%
# Average Age of patients 
avg_age=df['Age'].mean()
print("Average Age of Patients:",avg_age)

#Diabetes rate by Pregnancies
diabetes_by_pregnancies = df.groupby('Pregnancies')['Outcome'].mean()
print("Diabetes Rate by Pregnancies:\n", diabetes_by_pregnancies)

#Average BMI of patient with Diabetes
avg_bmi = df[df['Outcome'] == 1]['BMI'].mean()
print('Average BMI of Diabetes Patients:', avg_bmi)

#Average Glucose Level of PAtient with Duabetes
avg_glcs=df[df['Outcome']==1]['Glucose'].mean()
print("Average Glucose Levels of Patients",avg_glcs)
# Diabetes rate by Age
diabetes_by_age = df.groupby('Age')['Outcome'].mean()
print("Diabetes Rate by Age:\n", diabetes_by_age)
# Out:
# Average Age of Patients: 33.240885416666664
# Diabetes Rate by Pregnancies:
#  Pregnancies
# 0     0.342342
# 1     0.214815
# 2     0.184466
# 3     0.360000
# 4     0.338235
# 5     0.368421
# 6     0.320000
# 7     0.555556
# 8     0.578947
# 9     0.642857
# 10    0.416667
# 11    0.636364
# 12    0.444444
# 13    0.500000
# 14    1.000000
# 15    1.000000
# 17    1.000000
# Name: Outcome, dtype: float64
# Average BMI of Diabetes Patients: 35.14253731343284
# Average Glucose Levels of Patients 141.25746268656715
# Diabetes Rate by Age:
#  Age
# 21    0.079365
# 22    0.152778
# 23    0.184211
# 24    0.173913
# 25    0.291667
# 26    0.242424
# 27    0.250000
# 28    0.285714
# 29    0.448276
# 30    0.285714
# 31    0.541667
# 32    0.562500
# 33    0.588235
# 34    0.285714
# 35    0.500000
# 36    0.625000
# 37    0.315789
# 38    0.625000
# 39    0.250000
# 40    0.461538
# 41    0.590909
# 42    0.388889
# 43    0.846154
# 44    0.625000
# 45    0.533333
# 46    0.538462
# ...

# %% [markdown]
#  Insights:
#
# 1.Average age: ~33 years.
#
# 2.Diabetes is increased after age of 29
#
# 3 50% chance of getting diabetes for a person who is having more than 6 pregnencies

# %% [markdown]
# 7 visualization by Matplot

# %%
diabetes_rate_by_age = df.groupby('Age')['Outcome'].mean()

plt.figure(figsize=(10,6))
plt.plot(diabetes_rate_by_age.index, diabetes_rate_by_age.values, color='darkorange', marker='o')
plt.title('Diabetes Rate by Age')
plt.xlabel('Age')
plt.ylabel('Diabetes Rate')
plt.grid(True)
plt.show()

# %%
diabetes_rate_by_preg = df.groupby('Pregnancies')['Outcome'].mean()

plt.figure(figsize=(8,5))
plt.plot(diabetes_rate_by_preg.index, diabetes_rate_by_preg.values, marker='o', color='teal')
plt.title('Diabetes Rate by Number of Pregnancies')
plt.xlabel('Number of Pregnancies')
plt.ylabel('Diabetes Rate')
plt.grid(True)
plt.show()

# %% [markdown]
# 8 visualization with seaborn

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df[['Age', 'SkinThickness', 'Outcome']], hue='Outcome', palette='Set2')
plt.show()
